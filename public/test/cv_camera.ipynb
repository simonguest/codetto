# %%
import cv
import time

canvas = cv.get_canvas(640, 480)
camera = cv.start_camera(canvas)
time.sleep(0.5)  # let rAF loop draw a few frames on the main thread
camera.stop()

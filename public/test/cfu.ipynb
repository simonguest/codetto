# %% [markdown]
# # Check for Understanding Test
#
# Tests all three CFU question types.

# %% [raw]
# {
#   "question_type": "freeform",
#   "question": "In what year was Python created?",
#   "answer": "1991",
#   "submitted_answer": ""
# }

# %% [raw]
# {
#   "question_type": "multiple_choice",
#   "question": "Which of the following is not a Python package?",
#   "options": [
#     { "key": "a", "text": "pandas" },
#     { "key": "b", "text": "matplotlib" },
#     { "key": "c", "text": "ubuntu" },
#     { "key": "d", "text": "openai" }
#   ],
#   "answer": "c",
#   "submitted_answer": ""
# }

# %% [raw]
# {
#   "question_type": "true_false",
#   "question": "Python source files are designated as .py",
#   "answer": "True",
#   "submitted_answer": ""
# }

# %% [raw]
# {
#   "question_type": "true_false",
#   "question": "Python is a compiled language. (animation disabled on this one)",
#   "answer": "False",
#   "submitted_answer": "",
#   "animation": false
# }

# %% [markdown]
# # IPython Display Test
#
# Tests that `IPython.display.display()` renders a PIL image as a PNG.

# %%
from IPython.display import display
from PIL import Image

# Create a simple 100x100 blue image
img = Image.new("RGB", (100, 100), color=(0, 128, 255))
display(img)

# %% [markdown]
# # Matplotlib Test
#
# Tests that `matplotlib` renders a PNG plot in the output.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.title("Test Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

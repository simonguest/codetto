# %% [markdown]
# # Pandas Test
#
# Tests that `pandas` DataFrames are rendered as HTML tables.

# %%
import pandas as pd

data = {
  'Name': ['Alice', 'Bob', 'Charlie'],
  'Age': [25, 30, 35],
  'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)
df

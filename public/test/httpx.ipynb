# %% [markdown]
# # httpx Test
#
# Tests that `httpx` can make HTTP requests from within Pyodide.

# %%
import httpx

response = httpx.get("https://api.github.com/zen")
print(type(response).__name__)
print(response.status_code)

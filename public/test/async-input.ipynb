# %% [markdown]
# # Async Input Test
#
# Tests that `input()` correctly suspends execution and resumes with user-provided value.

# %%
age = input("What is your age? ")
print("You are " + age + " years old.")

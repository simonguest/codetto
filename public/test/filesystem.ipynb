# %%
import os

files = sorted(os.listdir('/sample_files'))
print('Files in /sample_files:')
for f in files:
    print(f'  {f}')
assert 'cat.png' in files, 'cat.png missing'
assert 'chime.wav' in files, 'chime.wav missing'
print('Listing OK')

# %%
import graphics

canvas = graphics.canvas(256, 256)
graphics.draw_image(canvas, '/sample_files/cat.png')
print('Image displayed OK')

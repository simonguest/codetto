# %%
import os

files = sorted(os.listdir('/sample_files'))
print('Files in /sample_files:')
for f in files:
    print(f'  {f}')
assert 'cat.jpg' in files, 'cat.jpg missing'
assert 'correct.wav' in files, 'correct.wav missing'
print('Listing OK')

# %%
import graphics

canvas = graphics.canvas(256, 256)
graphics.draw_image(canvas, '/sample_files/cat.jpg')
print('Image displayed OK')
